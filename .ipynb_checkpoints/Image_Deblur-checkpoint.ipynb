# %% [markdown]
# <h2>Image Deblurring for License Plate OCR</h2>

# %% [markdown]
# <h3>EDA</h3>

# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %%
# Paths
src_dir = 'testing_images/clear_images'
images = os.listdir(src_dir)
dst_dir = 'testing_images/blur_images'

# %%
img1 = cv2.imread(f"{src_dir}/{images[43]}")
img2 = cv2.imread(f"{src_dir}/{images[144]}")

blurred1 = cv2.GaussianBlur(img1, (15, 15), 0) 
blurred2 = cv2.GaussianBlur(img2, (15, 15), 0)  

img_rgb1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img_rgb2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
blurred_rgb1 = cv2.cvtColor(blurred1, cv2.COLOR_BGR2RGB)
blurred_rgb2 = cv2.cvtColor(blurred2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12,12))

plt.subplot(2, 2, 1)
plt.imshow(img_rgb1)
plt.title("Original1")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(img_rgb2)
plt.title("Original2")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(blurred_rgb1)
plt.title("Gaussian Blurred1")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(blurred_rgb2)
plt.title("Gaussian Blurred2")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %%
def applyGaussianBlur(i,img):
    img = cv2.imread(f"{src_dir}/{images[i]}")
    blur = cv2.GaussianBlur(img, (15, 15), 0)
    try:
        cv2.imwrite(f"{dst_dir}/{images[i]}", blur)
    except:
        print(f"Error writing image {images[i]}")

for i, img in tqdm(enumerate(images), total=len(images)):
    # applyGaussianBlur(i,img)
    pass

print('DONE')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 396/396 [00:00<?, ?it/s]
# DONE

# %%
# Checking that the blur and sharp images correspond correctly

gauss_blur = os.listdir(src_dir)
gauss_blur.sort()
sharp = os.listdir(dst_dir)
sharp.sort()

x_blur = []
for i in range(len(gauss_blur)):
    x_blur.append(gauss_blur[i])

y_sharp = []
for i in range(len(sharp)):
    y_sharp.append(sharp[i])

# Check .ipynb
print(len(x_blur))
print(len(y_sharp))
print(x_blur[1])
print(y_sharp[1])
# Out:
# 396
# 396
# 000228608388803f_jpg.rf.924b00a39d9fad9da20e784dacfc41b7.jpg
# 000228608388803f_jpg.rf.924b00a39d9fad9da20e784dacfc41b7.jpg

# %%
widths, heights = [], []
channels_list = []
pixel_means, pixel_mins, pixel_maxs = [], [], []
formats = []

for img_name in images:
    img_path = os.path.join(src_dir, img_name)
    img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)

    if img is None:
        print(f"Error reading {img_name}")
        continue

    h, w = img.shape[:2]
    widths.append(w)
    heights.append(h)

    if len(img.shape) == 2:
        channels_list.append("Grayscale")
    elif img.shape[2] == 3:
        channels_list.append("RGB")
    elif img.shape[2] == 4:
        channels_list.append("RGBA")
    else:
        channels_list.append(f"Unknown-{img.shape}")

    ext = os.path.splitext(img_name)[1].lower()
    formats.append(ext)

    pixel_mins.append(np.min(img))
    pixel_maxs.append(np.max(img))
    pixel_means.append(np.mean(img))

print("Dataset Summary")
print(f"Total images: {len(images)}")
print(f"Image formats: {set(formats)}")
print(f"Channel types: {set(channels_list)}")
print(f"Resolution (min WxH): {min(widths)}x{min(heights)}")
print(f"Resolution (max WxH): {max(widths)}x{max(heights)}")
print(f"Average resolution: {int(np.mean(widths))}x{int(np.mean(heights))}")
print(f"Pixel intensity range: {min(pixel_mins)} – {max(pixel_maxs)}")
print(f"Mean pixel intensity: {np.mean(pixel_means):.2f}")

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.hist([w*h for w,h in zip(widths, heights)], bins=20, color='skyblue')
plt.title("Image Size Distribution (total pixels)")
plt.xlabel("Pixels (W*H)")
plt.ylabel("Count")

plt.subplot(1,2,2)
plt.hist(pixel_means, bins=30, color='lightgreen')
plt.title("Mean Pixel Intensity Distribution")
plt.xlabel("Mean Intensity")
plt.ylabel("Count")

plt.tight_layout()
plt.show()
# Out:
# Dataset Summary
# Total images: 396
# Image formats: {'.jpg'}
# Channel types: {'RGB'}
# Resolution (min WxH): 640x640
# Resolution (max WxH): 640x640
# Average resolution: 640x640
# Pixel intensity range: 0 – 255
# Mean pixel intensity: 112.15

# %% [markdown]
# <h3>Model Architectures</h3>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(3, 128, kernel_size=5, padding=1)
        self.conv2 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 3, kernel_size=1, padding=1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        return x
    

class DeepCNN(nn.Module):
    def __init__(self):
        super(DeepCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(32, 16, kernel_size=3, padding=1)
        self.conv8 = nn.Conv2d(16, 3, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(128)
        self.bn4 = nn.BatchNorm2d(64)
        self.bn5 = nn.BatchNorm2d(64)
        self.bn6 = nn.BatchNorm2d(32)
        self.bn7 = nn.BatchNorm2d(16)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = F.relu(self.bn5(self.conv5(x)))
        x = F.relu(self.bn6(self.conv6(x)))
        x = F.relu(self.bn7(self.conv7(x)))
        x = self.conv8(x)
        return x

class SimpleAE(nn.Module):
    def __init__(self):
        super(SimpleAE, self).__init__()

        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=5),
            nn.ReLU(True),
            nn.Conv2d(32, 64, kernel_size=5),
            nn.ReLU(True))
        self.decoder = nn.Sequential(             
            nn.ConvTranspose2d(64, 32, kernel_size=5),
            nn.ReLU(True),
            nn.ConvTranspose2d(32, 3, kernel_size=5),
            nn.ReLU(True))
    def forward(self,x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# <h3> Models Testing

# %%
import os
import uuid
import zipfile
from pathlib import Path
from typing import Dict, Tuple, List

import cv2
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
from skimage.metrics import mean_squared_error, peak_signal_noise_ratio, structural_similarity
import pandas as pd
import matplotlib.pyplot as plt

# %%
MODELS_DIR = Path("app/models")
CNN_WEIGHTS = MODELS_DIR / "model_cnn.pth"
DEEPCNN_WEIGHTS = MODELS_DIR / "model_deepcnn.pth"
AE_WEIGHTS = MODELS_DIR / "model_sae.pth"

TEST_IMAGES_DIR = Path("testing_images") 
OUT_DIR = Path("test_run")
RESULTS_CSV = OUT_DIR / "results.csv"
OVERALL_CSV = OUT_DIR / "overall_metrics.csv"
ZIP_NAME = OUT_DIR / "test_results.zip"
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Current device :",DEVICE)
# Out:
# Current device : cuda:0

# %%
device = DEVICE

# Initialize models
cnn = CNN().to(device).eval()
deepcnn = DeepCNN().to(device).eval()
ae = SimpleAE().to(device).eval()

models_map = {
    "CNN": {"model": cnn, "weights": CNN_WEIGHTS, "metrics": []},
    "DeepCNN": {"model": deepcnn, "weights": DEEPCNN_WEIGHTS, "metrics": []},
    "SimpleAE": {"model": ae, "weights": AE_WEIGHTS, "metrics": []},
}

for name, entry in models_map.items():
    if entry["weights"].exists():
        raw = torch.load(str(entry["weights"]), map_location=device)
        if isinstance(raw, dict) and "state_dict" in raw:
            raw = raw["state_dict"]
        cleaned = {k.replace("module.", ""): v for k, v in raw.items()}
        try:
            entry["model"].load_state_dict(cleaned, strict=True)
        except:
            entry["model"].load_state_dict(cleaned, strict=False)
        print(f"{name} weights loaded.")
    else:
        print(f"{name} weights NOT found. Random init used.")
# Out:
# CNN weights loaded.
# DeepCNN weights loaded.
# SimpleAE weights loaded.

# %%
blur_dir = TEST_IMAGES_DIR / "blur_images"
gt_dir = TEST_IMAGES_DIR / "clear_images"

blur_images = sorted([p for p in blur_dir.glob("*") if p.suffix.lower() in (".jpg",".jpeg",".png",".bmp")])
gt_images_all = sorted([p for p in gt_dir.glob("*") if p.suffix.lower() in (".jpg",".jpeg",".png",".bmp")])

gt_map = {p.name: p for p in gt_images_all}
gt_images = [gt_map.get(p.name, None) for p in blur_images]

len(blur_images), len(gt_images)
# Out:
# (396, 396)

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

results = []  # will store dicts

# %%
for idx, bpath in enumerate(blur_images):
    img = cv2.imread(str(bpath), cv2.IMREAD_COLOR)
    if img is None:
        continue
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    inp = transform(img).unsqueeze(0).to(device)

    gtpath = gt_images[idx]
    if gtpath is not None:
        gt_img = cv2.imread(str(gtpath), cv2.IMREAD_COLOR)
        gt_img = cv2.cvtColor(gt_img, cv2.COLOR_BGR2RGB)
        gt_resized = cv2.resize(gt_img, (224,224))
        gt_np = (gt_resized.astype(np.float32))/255.0
    else:
        gt_np = None

    for mname, entry in models_map.items():
        with torch.no_grad():
            out = entry["model"](inp)
            if out.shape[-1] != 224 or out.shape[-2] != 224:
                out = F.interpolate(out, size=(224,224), mode='bilinear', align_corners=False)

        t = out[0].detach().cpu().numpy()
        t = np.transpose(t, (1,2,0))
        t = np.clip(t, 0.0, 1.0)

        row = {"image": bpath.name, "model": mname}

        if gt_np is not None:
            mse = float(mean_squared_error(gt_np, t))
            mae = float(np.mean(np.abs(gt_np - t)))
            try:
                psnr = float(peak_signal_noise_ratio(gt_np, t, data_range=1.0))
            except:
                psnr = float("nan")
            try:
                ssim = float(structural_similarity(gt_np, t, data_range=1.0, multichannel=True))
            except:
                ssim = float("nan")
            row.update({"mse": mse, "mae": mae, "psnr": psnr, "ssim": ssim})
            entry["metrics"].append(row)
        else:
            row.update({"mse": None, "mae": None, "psnr": None, "ssim": None})

        results.append(row)

    # print(f"Processed {idx+1}/{len(blur_images)}")
print("Process completed")
# Out:
# Process completed

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#                                                   image     model       mse  \
# 0     00009e5b390986a0_jpg.rf.04d1cbabbde68b6be73ada...       CNN  0.003505
# 1     00009e5b390986a0_jpg.rf.04d1cbabbde68b6be73ada...   DeepCNN  0.001962
# 2     00009e5b390986a0_jpg.rf.04d1cbabbde68b6be73ada...  SimpleAE  0.001763
# 3     000228608388803f_jpg.rf.924b00a39d9fad9da20e78...       CNN  0.001754
# 4     000228608388803f_jpg.rf.924b00a39d9fad9da20e78...   DeepCNN  0.001289
# ...                                                 ...       ...       ...
# 1183  990XHK_jpg.rf.6e89d00e723af5c7ad04b1f928998127...   DeepCNN  0.001200
# 1184  990XHK_jpg.rf.6e89d00e723af5c7ad04b1f928998127...  SimpleAE  0.000960
# 1185  990XHK_jpg.rf.889c0102efe068fb9a268986f13be649...       CNN  0.001067
# 1186  990XHK_jpg.rf.889c0102efe068fb9a268986f13be649...   DeepCNN  0.000797
# 1187  990XHK_jpg.rf.889c0102efe068fb9a268986f13be649...  SimpleAE  0.000699
#
#            mae       psnr  ssim
# 0     0.030884  24.553606   NaN
# 1     0.032459  27.073662   NaN
# 2     0.028247  27.537655   NaN
# 3     0.019396  27.559853   NaN
# 4     0.024362  28.895977   NaN
# ...        ...        ...   ...
# 1183  0.024462  29.206469   NaN
# 1184  0.018164  30.179022   NaN
# 1185  0.015950  29.718699   NaN
# 1186  0.019867  30.985893   NaN
# 1187  0.014517  31.553048   NaN
#
# [1188 rows x 6 columns]

# %%
summary = []
for mname, entry in models_map.items():
    if not entry["metrics"]:
        continue
    dfm = pd.DataFrame(entry["metrics"])
    summary.append({
        "model": mname,
        "mse_mean": dfm["mse"].mean(),
        "mae_mean": dfm["mae"].mean(),
        "psnr_mean": dfm["psnr"].mean(),
        "ssim_mean": dfm["ssim"].mean(),
    })

summary_df = pd.DataFrame(summary)
summary_df
# Out:
#       model  mse_mean  mae_mean  psnr_mean  ssim_mean
# 0       CNN  0.002519  0.019754  26.549573        NaN
# 1   DeepCNN  0.001277  0.024155  29.378074        NaN
# 2  SimpleAE  0.001052  0.017902  30.355524        NaN

# %%
metrics_to_plot = ["mse_mean", "mae_mean", "psnr_mean", "ssim_mean"]

for metric in metrics_to_plot:
    plt.figure(figsize=(6,4))
    plt.bar(summary_df["model"], summary_df[metric])
    plt.title(f"{metric} comparison across models")
    plt.ylabel(metric)
    plt.xlabel("Model")
    plt.show()

# %%
from app.processing.plate_detection import plate_detection_and_ocr
INPUT_DIR = Path("testing_images/ocrtest")  # folder with 20 images
OUTPUT_DIR = Path("testing_images/ocrout")  # where we'll save ONLY OCR-ready outputs
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

test_images = sorted([p for p in INPUT_DIR.glob("*") if p.suffix.lower() in (".jpg",".jpeg",".png",".bmp")])
len(test_images)
# Out:
# 15

# %%
import uuid
from PIL import Image
import pandas as pd
import cv2
import torch
import numpy as np

results = []  # each row: image, model, output_img, extracted_text

for img_path in test_images:
    img_bgr = cv2.imread(str(img_path))
    if img_bgr is None:
        continue

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    inp = transform(img_rgb).unsqueeze(0).to(device)

    for mname, entry in models_map.items():
        model = entry["model"]
        with torch.no_grad():
            out = model(inp)
            if out.shape[-1] != 224 or out.shape[-2] != 224:
                out = F.interpolate(out, size=(224,224), mode='bilinear', align_corners=False)

        arr = out[0].detach().cpu().numpy()
        arr = np.transpose(arr, (1,2,0))
        arr = np.clip(arr, 0, 1)
        arr_uint8 = (arr * 255).astype(np.uint8)

        out_name = f"{img_path.stem}{mname}{uuid.uuid4().hex}.jpg"
        out_path = OUTPUT_DIR / out_name

        cv2.imwrite(str(out_path), cv2.cvtColor(arr_uint8, cv2.COLOR_RGB2BGR))

        extracted_text, final_img_after_yolo = plate_detection_and_ocr(str(out_path))

        results.append({
            "image": img_path.name,
            "model": mname,
            "output_file": out_name,
            "ocr_text": extracted_text
        })
# Out:
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb4151e9027eCNNff7ea3f13a774d249f55df694dd57018.jpg: 640x640 1 license_plate, 52.7ms
# Speed: 6.7ms preprocess, 52.7ms inference, 140.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: CV-1897
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb4151e9027eDeepCNNe47e9d7153474ea48d83dabb6d298b66.jpg: 640x640 1 license_plate, 30.8ms
# Speed: 5.6ms preprocess, 30.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: CV-1897
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb4151e9027eSimpleAEf7bb09ee60d746659b6652f8d5f075cb.jpg: 640x640 1 license_plate, 26.8ms
# Speed: 5.5ms preprocess, 26.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: CV-1897
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc
7602
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate3CNNc73c86c17bf54d3e99fef3367d78bf79.jpg: 640x640 1 license_plate, 24.4ms
# Speed: 4.6ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: LR33TEE
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate3DeepCNNd7be57cc3ed04702ae91042a7753eee3.jpg: 640x640 1 license_plate, 24.4ms
# Speed: 4.7ms preprocess, 24.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: BLUR33TEE
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate3SimpleAE2aef3691c7884925b3dd8a03c5290c70.jpg: 640x640 1 license_plate, 25.4ms
# Speed: 7.0ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: L.R33TEE
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate5CNNbbc17703d1594e7c853991f6693528a6.jpg: 640x640 1 license_plate, 24.5ms
# Speed: 4.9ms preprocess, 24.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: WO-71817
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate5DeepCNNa39f675c3ebe4768b9308ef076ce7eac.jpg: 640x640 1 license_plate, 23.4ms
# Speed: 5.4ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: WD-71817
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate5SimpleAEda6533d8db0b4f1a92bff7d1752e81a5.jpg: 640x640 1 license_plate, 23.4ms
# Speed: 7.0ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate:
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate6CNN8743441a6bb34a138fb4a33929fe9bda.jpg: 640x640 1 license_plate, 23.4ms
# Speed: 5.2ms preprocess, 23.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 68-S9 4964
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate6DeepCNNdb54756cc6174506b9f960000d64cb6f.jpg: 640x640 1 license_plate, 23.6ms
# Speed: 4.8ms preprocess, 23.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 68-S9 4964
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrout\plate6SimpleAEdc0a79cd6d5845e2a5e2e0b618743357.jpg: 640x640 1 license_plate, 24.0ms
# Speed: 5.2ms preprocess, 24.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 68-S9 4964

# %%
df = pd.DataFrame(results)
df
# Out:
#                                                 image     model  \
# 0   013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...       CNN
# 1   013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...   DeepCNN
# 2   013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...  SimpleAE
# 3   0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc1e...       CNN
# 4   0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc1e...   DeepCNN
# 5   0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc1e...  SimpleAE
# 6   025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...       CNN
# 7   025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...   DeepCNN
# 8   025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...  SimpleAE
# 9   0293f5c3f0650423_jpg.rf.5f5d2c1cc697d05550caa7...       CNN
# 10  0293f5c3f0650423_jpg.rf.5f5d2c1cc697d05550caa7...   DeepCNN
# 11  0293f5c3f0650423_jpg.rf.5f5d2c1cc697d05550caa7...  SimpleAE
# 12  029ca9b64cfc78a4_jpg.rf.a715a67e78e42388e025b4...       CNN
# 13  029ca9b64cfc78a4_jpg.rf.a715a67e78e42388e025b4...   DeepCNN
# 14  029ca9b64cfc78a4_jpg.rf.a715a67e78e42388e025b4...  SimpleAE
# 15  1-placa-mexicana-del-estado-de-guerrero-2015-h...       CNN
# 16  1-placa-mexicana-del-estado-de-guerrero-2015-h...   DeepCNN
# 17  1-placa-mexicana-del-estado-de-guerrero-2015-h...  SimpleAE
# 18  270721_jpg.rf.126170f6a7767b02941ea6563818080a...       CNN
# 19  270721_jpg.rf.126170f6a7767b02941ea6563818080a...   DeepCNN
# 20  270721_jpg.rf.126170f6a7767b02941ea6563818080a...  SimpleAE
# 21  3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...       CNN
# 22  3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...   DeepCNN
# 23  3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...  SimpleAE
# 24  42-s-l640_jpg.rf.a1cc188826dc444b691928bb1cd67...       CNN
# 25  42-s-l640_jpg.rf.a1cc188826dc444b691928bb1cd67...   DeepCNN
# 26  42-s-l640_jpg.rf.a1cc188826dc444b691928bb1cd67...  SimpleAE
# 27  56-800px-1950_Indiana_license_plate_jpg.rf.f7a...       CNN
# 28  56-800px-1950_Indiana_license_plate_jpg.rf.f7a...   DeepCNN
# 29  56-800px-1950_Indiana_license_plate_jpg.rf.f7a...  SimpleAE
# 30  5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...       CNN
# 31  5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...   DeepCNN
# 32  5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...  SimpleAE
# 33                                         plate2.jpg       CNN
# 34                                         plate2.jpg   DeepCNN
# 35                                         plate2.jpg  SimpleAE
# 36                                         plate3.jpg       CNN
# 37                                         plate3.jpg   DeepCNN
# 38                                         plate3.jpg  SimpleAE
# 39                                         plate5.jpg       CNN
# 40                                         plate5.jpg   DeepCNN
# 41                                         plate5.jpg  SimpleAE
# 42                                         plate6.jpg       CNN
# 43                                         plate6.jpg   DeepCNN
# 44                                         plate6.jpg  SimpleAE
#
#                                           output_file  \
# 0   013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...
# 1   013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...
# 2   013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...
# 3   0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc1e...
# 4   0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc1e...
# 5   0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc1e...
# 6   025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...
# 7   025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...
# 8   025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...
# 9   0293f5c3f0650423_jpg.rf.5f5d2c1cc697d05550caa7...
# 10  0293f5c3f0650423_jpg.rf.5f5d2c1cc697d05550caa7...
# 11  0293f5c3f0650423_jpg.rf.5f5d2c1cc697d05550caa7...
# 12  029ca9b64cfc78a4_jpg.rf.a715a67e78e42388e025b4...
# 13  029ca9b64cfc78a4_jpg.rf.a715a67e78e42388e025b4...
# 14  029ca9b64cfc78a4_jpg.rf.a715a67e78e42388e025b4...
# 15  1-placa-mexicana-del-estado-de-guerrero-2015-h...
# 16  1-placa-mexicana-del-estado-de-guerrero-2015-h...
# 17  1-placa-mexicana-del-estado-de-guerrero-2015-h...
# 18  270721_jpg.rf.126170f6a7767b02941ea6563818080a...
# 19  270721_jpg.rf.126170f6a7767b02941ea6563818080a...
# 20  270721_jpg.rf.126170f6a7767b02941ea6563818080a...
# 21  3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...
# 22  3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...
# 23  3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...
# 24  42-s-l640_jpg.rf.a1cc188826dc444b691928bb1cd67...
# 25  42-s-l640_jpg.rf.a1cc188826dc444b691928bb1cd67...
# 26  42-s-l640_jpg.rf.a1cc188826dc444b691928bb1cd67...
# 27  56-800px-1950_Indiana_license_plate_jpg.rf.f7a...
# 28  56-800px-1950_Indiana_license_plate_jpg.rf.f7a...
# 29  56-800px-1950_Indiana_license_plate_jpg.rf.f7a...
# 30  5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...
# 31  5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...
# 32  5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...
# 33      plate2CNN25a36fe6a03d44068ea211e2f6e40124.jpg
# 34  plate2DeepCNN17f0dbff3e614cbc84ee9fcebeb7ae42.jpg
# 35  plate2SimpleAEda64b73258b941608932bfbd175e0532...
# 36      plate3CNNc73c86c17bf54d3e99fef3367d78bf79.jpg
# 37  plate3DeepCNNd7be57cc3ed04702ae91042a7753eee3.jpg
# 38  plate3SimpleAE2aef3691c7884925b3dd8a03c5290c70...
# 39      plate5CNNbbc17703d1594e7c853991f6693528a6.jpg
# 40  plate5DeepCNNa39f675c3ebe4768b9308ef076ce7eac.jpg
# 41  plate5SimpleAEda6533d8db0b4f1a92bff7d1752e81a5...
# 42      plate6CNN8743441a6bb34a138fb4a33929fe9bda.jpg
# 43  plate6DeepCNNdb54756cc6174506b9f960000d64cb6f.jpg
# 44  plate6SimpleAEdc0a79cd6d5845e2a5e2e0b618743357...
#
#                            ocr_text
# 0                           CV-1897
# 1                           CV-1897
# 2                           CV-1897
# 3                           BPI2EFS
# 4                           BPI2EFS
# 5                           BPI2EFS
# 6                            eciloe
# 7                          R eiloae
# 8                            eeiloe
# 9                            173-61
# 10                           173-61
# 11                            73-61
# 12                          IAATULL
# 13                          IAATULL
# 14                          IAATULL
# 15               GUERRERO HA-9354-A
# 16             GUERRERO HA GUERRERO
# 17             GUERRERO HA GUERRERO
# 18                           8H7A8S
# 19                           8H7A8S
# 20                           8H7A8S
# 21               GUERRERO GZU-196-A
# 22               GUERRERO GZU-196-A
# 23               GUERRERO GZU-196-A
# 24   Guerrero 1 GZ-25-586 12 GROMEX
# 25  Guerrero  0 GZ-25-586 12 GROMEX
# 26     Guerrero GZ-25-586 12 GROMEX
# 27                50 MM2622 INDIANA
# 28                50 MM2622 INDIANA
# 29                50 MM2622 INDIANA
# 30                             京A 2
# 31                            京A 3Y
# 32                               京A
# 33                       HH20EE7602
# 34                        M20EE7602
# 35                       NH2DEE7602
# 36                          LR33TEE
# 37                        BLUR33TEE
# 38                         L.R33TEE
# 39                         WO-71817
# 40                         WD-71817
# 41
# 42                       68-S9 4964
# 43                       68-S9 4964
# 44                       68-S9 4964

# %%
import pandas as pd
from pathlib import Path

# ✅ MODIFY THIS to the actual dataset root folder
DATASET_DIR = Path("testing_images")   # e.g., "./AOLP" or "./OpenALPR" etc.
IMG_DIR = DATASET_DIR / "ocrtest"
LABELS_CSV = DATASET_DIR / "labels.csv"

# Load CSV containing ground-truth labels
df_labels = pd.read_csv(LABELS_CSV)

# Full paths for each image
df_labels["full_path"] = df_labels["filename"].apply(lambda x: str(IMG_DIR / x))
df_labels.head()
# Out:
#                                             filename                 label  \
# 0  1-placa-mexicana-del-estado-de-guerrero-2015-h...  GUERRERO HA - 9354-A
# 1  3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...  GUERRERO GZU - 196-A
# 2  5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...              A D003V5
# 3  013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...               CV-1897
# 4  025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...                2988FB
#
#                                            full_path
# 0  testing_images\ocrtest\1-placa-mexicana-del-es...
# 1  testing_images\ocrtest\3-D_NQ_NP_862473-MLM311...
# 2  testing_images\ocrtest\5c52d1a1a3106c65fff8201...
# 3  testing_images\ocrtest\013d1f1e520e0671_jpg.rf...
# 4  testing_images\ocrtest\025c30962ae5b499_jpg.rf...

# %%
import uuid
import cv2
import numpy as np
import torch
import torch.nn.functional as F
from difflib import SequenceMatcher

results = []

def text_similarity(a, b):
    if not isinstance(a, str): a = '' if a is None else str(a)
    if not isinstance(b, str): b = '' if b is None else str(b)
    return SequenceMatcher(None, a.strip(), b.strip()).ratio()

for _, row in df_labels.iterrows():
    img_path = row["full_path"]
    gt_text = row["label"]   # ground-truth

    img_bgr = cv2.imread(img_path)
    if img_bgr is None:
        continue

    # 1) OCR on ORIGINAL
    ocr_orig, _ = plate_detection_and_ocr(img_path)

    row_result = {
        "image": Path(img_path).name,
        "ground_truth": gt_text,
        "ocr_original": ocr_orig
    }

    # Preprocess for the models
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    inp = transform(img_rgb).unsqueeze(0).to(device)

    # 2) OCR on each deblurred model output
    for mname, entry in models_map.items():
        model = entry["model"]
        with torch.no_grad():
            out = model(inp)
            if out.shape[-1] != 224 or out.shape[-2] != 224:
                out = F.interpolate(out, size=(224,224), mode='bilinear', align_corners=False)

        arr = out[0].cpu().numpy()
        arr = np.transpose(arr, (1,2,0))
        arr = np.clip(arr, 0, 1)
        arr_uint8 = (arr * 255).astype(np.uint8)

        # Save deblurred image if needed
        # out_name = f"{Path(img_path).stem}{mname}{uuid.uuid4().hex}.jpg"
        # out_path = OUTPUT_DIR / out_name
        # cv2.imwrite(str(out_path), cv2.cvtColor(arr_uint8, cv2.COLOR_RGB2BGR))

        # We can OCR directly from array by temporarily writing to disk OR modify plate_detection
        temp_path = f"temp_{mname}_{uuid.uuid4().hex}.jpg"
        cv2.imwrite(temp_path, cv2.cvtColor(arr_uint8, cv2.COLOR_RGB2BGR))

        ocr_text, _ = plate_detection_and_ocr(temp_path)
        row_result[f"{mname}_text"] = ocr_text

    results.append(row_result)

df_results = pd.DataFrame(results)
df_results
# Out:
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrtest\1-placa-mexicana-del-estado-de-guerrero-2015-ha-D_NQ_NP_781642-MLM31170295955_062019-F_jpg.rf.9975c630998044dfbe03321f4636a67b.jpg: 640x640 1 license_plate, 58.4ms
# Speed: 5.2ms preprocess, 58.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Pl
7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 8H7A8S
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrtest\plate2.jpg: 448x640 1 license_plate, 17.3ms
# Speed: 3.6ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Detected License Plate: MH20EE 7602
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_CNN_c8dcefa7bde245138ec44d8ad66ec737.jpg: 640x640 1 license_plate, 25.1ms
# Speed: 5.3ms preprocess, 25.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: HH20EE7602
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_DeepCNN_00978dfb8f8348ea8f955971bd07a4c7.jpg: 640x640 1 license_plate, 23.7ms
# Speed: 4.8ms preprocess, 23.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: M20EE7602
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_SimpleAE_f01b3584de5e489185f3b81876e9f6ed.jpg: 640x640 1 license_plate, 23.4ms
# Speed: 5.4ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: NH2DEE7602
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrtest\plate3.jpg: 448x640 1 license_plate, 17.4ms
# Speed: 3.2ms preprocess, 17.4ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Detected License Plate: LR33TEE 8B
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_CNN_a3211c5d67b647f2a496e80e60e7db8f.jpg: 640x640 1 license_plate, 24.8ms
# Speed: 5.3ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: LR33TEE
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_DeepCNN_a1ed298929934be29b620306eab7311e.jpg: 640x640 1 license_plate, 23.0ms
# Speed: 5.3ms preprocess, 23.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: BLUR33TEE
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_SimpleAE_4f84fc90a8624031a28500f652232f3d.jpg: 640x640 1 license_plate, 22.8ms
# Speed: 5.2ms preprocess, 22.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: L.R33TEE
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrtest\plate5.jpg: 416x640 1 license_plate, 15.7ms
# Speed: 2.6ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# Detected License Plate: WO-71817
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_CNN_63e0f1d5ee6142dda2835dec267d5a0e.jpg: 640x640 1 license_plate, 24.1ms
# Speed: 5.0ms preprocess, 24.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: WO-71817
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_DeepCNN_73679e605c814d7791dbea2f5fc5b09d.jpg: 640x640 1 license_plate, 22.8ms
# Speed: 5.2ms preprocess, 22.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: WD-71817
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_SimpleAE_089c4386b3d44c59892d6a232797a10b.jpg: 640x640 1 license_plate, 23.4ms
# Speed: 4.8ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate:
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\testing_images\ocrtest\plate6.jpg: 640x640 1 license_plate, 22.9ms
# Speed: 4.8ms preprocess, 22.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 68-S9 4964
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_CNN_e7af29201b8e4feb9f850ede7eefd3c9.jpg: 640x640 1 license_plate, 22.8ms
# Speed: 5.2ms preprocess, 22.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 68-S9 4964
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_DeepCNN_edf90405db9b4e989fa313b226d9234d.jpg: 640x640 1 license_plate, 22.8ms
# Speed: 6.2ms preprocess, 22.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 68-S9 4964
#
# image 1/1 C:\Users\Mihir\Desktop\DL Project\temp_SimpleAE_db4bdbdad7414ea1a67d46d6249f5d43.jpg: 640x640 1 license_plate, 23.7ms
# Speed: 5.3ms preprocess, 23.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected License Plate: 68-S9 4964
#                                                 image  \
# 0   1-placa-mexicana-del-estado-de-guerrero-2015-h...
# 1   3-D_NQ_NP_862473-MLM31170298229_062019-W_jpg.r...
# 2   5c52d1a1a3106c65fff82019_jpeg_jpg.rf.a8493ac6e...
# 3   013d1f1e520e0671_jpg.rf.a1cd4fd8bad3a50a56f3cb...
# 4   025c30962ae5b499_jpg.rf.fd1f18f07fd59c0cf92024...
# 5   029ca9b64cfc78a4_jpg.rf.a715a67e78e42388e025b4...
# 6   42-s-l640_jpg.rf.a1cc188826dc444b691928bb1cd67...
# 7   56-800px-1950_Indiana_license_plate_jpg.rf.f7a...
# 8   0195e8a172eddc29_jpg.rf.0297b6c2f63f13977bdc1e...
# 9   0293f5c3f0650423_jpg.rf.5f5d2c1cc697d05550caa7...
# 10  270721_jpg.rf.126170f6a7767b02941ea6563818080a...
# 11                                         plate2.jpg
# 12                                         plate3.jpg
# 13                                         plate5.jpg
# 14                                         plate6.jpg
#
#                     ground_truth                      ocr_original  \
# 0           GUERRERO HA - 9354-A                GUERRERO HA:9354-A
# 1           GUERRERO GZU - 196-A                GUERRERO GZU-196-A
# 2                       A D003V5                                京A
# 3                        CV-1897                           CV-1897
# 4                         2988FB                            eeiloa
# 5                        1447ULL                           IAATULL
# 6   Guerrero GZ-25-586 12 GROMEX  Guerrero Ea GZ-25-586 12 GRO MEX
# 7              50 MM2622 INDIANA                 50 MM2622 INDIANA
# 8                        BPI2EFS                           BPI2EFS
# 9                          73-61                             73-61
# 10                        8HF48S                            8H7481
# 11                    MH20EE7602                       MH20EE 7602
# 12                       LR33TEE                        LR33TEE 8B
# 13                      WD-71817                          WO-71817
# 14                    68-S9 4964                        68-S9 4964
#
#                           CNN_text                     DeepCNN_text  \
# 0               GUERRERO HA-9354-A             GUERRERO HA GUERRERO
# 1               GUERRERO GZU-196-A               GUERRERO GZU-196-A
# 2                             京A 2                            京A 3Y
# 3                          CV-1897                          CV-1897
# 4                           eciloe                         R eiloae
# 5                          IAATULL                          IAATULL
# 6   Guerrero 1 GZ-25-586 12 GROMEX  Guerrero  0 GZ-25-586 12 GROMEX
# 7                50 MM2622 INDIANA                50 MM2622 INDIANA
# 8                          BPI2EFS                          BPI2EFS
# 9                           173-61                           173-61
# 10                          8H7A8S                           8H7A8S
# 11                      HH20EE7602                        M20EE7602
# 12                         LR33TEE                        BLUR33TEE
# 13                        WO-71817                         WD-71817
# 14                      68-S9 4964                       68-S9 4964
#
#                    SimpleAE_text
# 0           GUERRERO HA GUERRERO
# 1             GUERRERO GZU-196-A
# 2                             京A
# 3                        CV-1897
# 4                         eeiloe
# 5                        IAATULL
# 6   Guerrero GZ-25-586 12 GROMEX
# 7              50 MM2622 INDIANA
# 8                        BPI2EFS
# 9                          73-61
# 10                        8H7A8S
# 11                    NH2DEE7602
# 12                      L.R33TEE
# 13
# 14                    68-S9 4964

# %%
import numpy as np

scores = {
    "orig": [],
    "CNN": [],
    "DeepCNN": [],
    "SimpleAE": []
}

for _, r in df_results.iterrows():
    gt = r["ground_truth"]
    
    # Original
    sim_orig = text_similarity(gt, r["ocr_original"])
    scores["orig"].append(sim_orig)

    for model_name in ["CNN", "DeepCNN", "SimpleAE"]:
        tm = r.get(f"{model_name}_text", "")
        scores[model_name].append(text_similarity(gt, tm))

accuracy_summary = {
    m: np.mean(vals) if len(vals) else 0 for m, vals in scores.items()
}

print("\nOCR Accuracy vs Ground Truth:")
for m, acc in accuracy_summary.items():
    print(f"{m}: {acc:.3f}")
# Out:
# OCR Accuracy vs Ground Truth:
# orig: 0.781
# CNN: 0.798
# DeepCNN: 0.786
# SimpleAE: 0.705
